# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51899/Aiml_2025/blob/main/Aiml_2025_lab_06_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
df=pd.read_table('/Classified_Data (1).txt',sep=',',index_col=0)
df.head()
# Out:
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608  0.759697
# 1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450  0.675334
# 2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781  1.626351
# 3  1.234204  1.386726  0.653046  0.825624  1.142504  0.875128  1.409708
# 4  1.279491  0.949750  0.627280  0.668976  1.232537  0.703727  1.115596
#
#         PJF       HQE       NXJ  TARGET CLASS
# 0  0.643798  0.879422  1.231409             1
# 1  1.013546  0.621552  1.492702             0
# 2  1.154483  0.957877  1.285597             0
# 3  1.380003  1.522692  1.153093             1
# 4  0.646691  1.463812  1.419167             1

# %%
print(df['WTT'].dtype)
# Out:
# float64

# %%
df = pd.read_csv('/Classified_Data (2).txt')
summary = df.describe(percentiles=[.25, .5, .75])
percentile_90 = df.quantile(0.90)
summary.loc['90%'] = percentile_90
print(summary)
# Out:
#         Unnamed: 0          WTT          PTI          EQW          SBI  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    499.500000     0.949682     1.114303     0.834127     0.682099
# std     288.819436     0.289635     0.257085     0.291554     0.229645
# min       0.000000     0.174412     0.441398     0.170924     0.045027
# 25%     249.750000     0.742358     0.942071     0.615451     0.515010
# 50%     499.500000     0.940475     1.118486     0.813264     0.676835
# 75%     749.250000     1.163295     1.307904     1.028340     0.834317
# max     999.000000     1.721779     1.833757     1.722725     1.634884
# 90%     899.100000     1.336612     1.441901     1.223127     0.983470
#
#                LQE          QWG          FDJ          PJF          HQE  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.032336     0.943534     0.963422     1.071960     1.158251
# ...

# %%
df = pd.read_csv('/Classified_Data (3).txt')
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['Unnamed: 0', 'WTT', 'PTI', 'EQW', 'SBI', 'LQE', 'QWG', 'FDJ', 'PJF', 'HQE', 'NXJ', 'TARGET CLASS']

# %%
from sklearn.preprocessing import StandardScaler
df = pd.read_csv('/Classified_Data (3).txt')
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_data, columns=df.columns)
print(scaled_df.head())
# Out:
#    Unnamed: 0       WTT       PTI       EQW       SBI       LQE       QWG  \
# 0   -1.730320 -0.123542  0.185907 -0.913431  0.319629 -1.033637 -2.308375
# 1   -1.726856 -1.084836 -0.430348 -1.025313  0.625388 -0.444847 -1.152706
# 2   -1.723391 -0.788702  0.339318  0.301511  0.755873  2.031693 -0.870156
# 3   -1.719927  0.982841  1.060193 -0.621399  0.625299  0.452820 -0.267220
# 4   -1.716463  1.139275 -0.640392 -0.709819 -0.057175  0.822886 -0.936773
#
#         FDJ       PJF       HQE       NXJ  TARGET CLASS
# 0 -0.798951 -1.482368 -0.949719 -0.643314           1.0
# 1 -1.129797 -0.202240 -1.828051  0.636759          -1.0
# 2  2.599818  0.285707 -0.682494 -0.377850          -1.0
# 3  1.750208  1.066491  1.241325 -1.026987           1.0
# 4  0.596782 -1.472352  1.040772  0.276510           1.0

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
scaler.fit(df.drop('TARGET CLASS',axis=1))
scaled_features=scaler.transform(df.drop('TARGET CLASS',axis=1))

# %%
df_feat=pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_feat.head()
# Out:
#    Unnamed: 0       WTT       PTI       EQW       SBI       LQE       QWG  \
# 0   -1.730320 -0.123542  0.185907 -0.913431  0.319629 -1.033637 -2.308375
# 1   -1.726856 -1.084836 -0.430348 -1.025313  0.625388 -0.444847 -1.152706
# 2   -1.723391 -0.788702  0.339318  0.301511  0.755873  2.031693 -0.870156
# 3   -1.719927  0.982841  1.060193 -0.621399  0.625299  0.452820 -0.267220
# 4   -1.716463  1.139275 -0.640392 -0.709819 -0.057175  0.822886 -0.936773
#
#         FDJ       PJF       HQE       NXJ
# 0 -0.798951 -1.482368 -0.949719 -0.643314
# 1 -1.129797 -0.202240 -1.828051  0.636759
# 2  2.599818  0.285707 -0.682494 -0.377850
# 3  1.750208  1.066491  1.241325 -1.026987
# 4  0.596782 -1.472352  1.040772  0.276510

# %%
from sklearn.model_selection import train_test_split
X=df_feat
y=df['TARGET CLASS']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=101)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.

# %%
pred=knn.predict(X_test)

# %% [markdown]
# part 3

# %%
from sklearn.metrics import classification_report,confusion_matrix
conf_mat=confusion_matrix(y_test,pred)
print(conf_mat)
# Out:
# [[95 11]
#  [ 7 87]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91       106
#            1       0.89      0.93      0.91        94
#
#     accuracy                           0.91       200
#    macro avg       0.91      0.91      0.91       200
# weighted avg       0.91      0.91      0.91       200

# %%
print("misclassification error rate:",round(np.mean(pred!=y_test),3))
# Out:
# misclassification error rate: 0.09
